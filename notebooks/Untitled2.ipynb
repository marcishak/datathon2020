# %%
# %reload_kedro
df = catalog.load("hospital_beds_raw")
import pandas as pd
# Out:
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2020-10-04 00:49:20,883 - root - INFO - ** Kedro project Datathon 2020
# 2020-10-04 00:49:20,884 - root - INFO - Defined global variable `context` and `catalog`
# 2020-10-04 00:49:20,894 - root - INFO - Registered line magic `run_viz`
# 2020-10-04 00:49:20,896 - kedro.io.data_catalog - INFO - Loading data from `hospital_beds_raw` (CSVDataSet)...

# %%
df.head()
# Out:
#   Country Name Country Code                    Indicator Name  Indicator Code  \
# 0        Aruba          ABW  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 1  Afghanistan          AFG  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 2       Angola          AGO  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 3      Albania          ALB  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
# 4      Andorra          AND  Hospital beds (per 1,000 people)  SH.MED.BEDS.ZS
#
#        1960  1961  1962  1963  1964  1965  ...  2011  2012  2013  2014  2015  \
# 0       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 1  0.170627   NaN   NaN   NaN   NaN   NaN  ...   0.4   0.5   0.5   0.5   0.5
# 2  2.061462   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# 3  5.102676   NaN   NaN   NaN   NaN   NaN  ...   2.6   2.9   2.9   NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#    2016  2017  2018  2019  Unnamed: 64
# 0   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %%
df2 = pd.melt(df, ["Country Name","Country Code","Indicator Name","Indicator Code"])
df3 = df2[df2['variable'] != "Unnamed: 64"].dropna().sort_values("variable").groupby(["Country Name","Country Code"]).agg({"variable" : "last",
                                                                                                   "value": "last"}).reset_index()

df3.columns = ["Country Name","Country Code", "year","hospital_beds_per_1000"] 
df3
# Out:
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            Country Name Country Code  year  hospital_beds_per_1000
# 0           Afghanistan          AFG  2015                0.500000
# 1               Albania          ALB  2013                2.900000
# 2               Algeria          DZA  2015                1.900000
# 3               Andorra          AND  2009                2.500000
# 4                Angola          AGO  2005                0.800000
# ..                  ...          ...   ...                     ...
# 241  West Bank and Gaza          PSE  1996                1.200000
# 242               World          WLD  2011                2.704488
# 243         Yemen, Rep.          YEM  2014                0.700000
# 244              Zambia          ZMB  2010                2.000000
# 245            Zimbabwe          ZWE  2011                1.700000
#
# [246 rows x 4 columns]

# %%
def get_latest_info_WB(df: pd.DataFrame, col: str) -> pd.DataFrame:
    df2 = pd.melt(
        df, ["Country Name", "Country Code", "Indicator Name", "Indicator Code"]
    def get_latest_info_WB(df: pd.DataFrame, col: str) -> pd.DataFrame:
    df2 = pd.melt(
        df, ["Country Name", "Country Code", "Indicator Name", "Indicator Code"]
    )
    df3 = (
        df2[df2["variable"] != "Unnamed: 64"]
        .dropna()
        .sort_values("variable")
        .groupby(["Country Name", "Country Code"])
        .agg({"variable": "last", "value": "last"})
        .reset_index()
    )
    df3.columns = ["Country Name", "Country Code", "year", col]
    return df3

    df3 = (
        df2[df2["variable"] != "Unnamed: 64"]
        .dropna()
        .sort_values("variable")
        .groupby(["Country Name", "Country Code"])
        .agg({"variable": "last", "value": "last"})
        .reset_index()
    )
    df3.columns = ["Country Name", "Country Code", "year", col]
    return df3
# Out:
#   File "<ipython-input-34-25dd1bed9788>", line 4
#     def get_latest_info_WB(df: pd.DataFrame, col: str) -> pd.DataFrame:
#       ^
# SyntaxError: invalid syntax

# %%
test = pd.DataFrame()
test.merge(df3)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-36-ef379108351d> in <module>
#       1 test = pd.DataFrame()
# ----> 2 test.merge(df3)
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7956             copy=copy,
#    7957             indicator=indicator,
# -> 7958             validate=validate,
#    7959         )
#    7960
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
#     646
#     647         # note this function has side effects
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1213                 if len(common_cols) == 0:
#    1214                     raise MergeError(
# -> 1215                         "No common columns to perform merge on. "
#    1216                         f"Merge options: left_on={self.left_on}, "
#    1217                         f"right_on={self.right_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False
