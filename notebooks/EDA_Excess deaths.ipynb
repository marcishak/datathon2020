# %%
# %reload_kedro
df = catalog.load("raw_excess_deaths")
# Out:
# 2020-10-03 18:09:19,770 - root - INFO - ** Kedro project Datathon 2020
# 2020-10-03 18:09:19,770 - root - INFO - Defined global variable `context` and `catalog`
# 2020-10-03 18:09:19,791 - root - INFO - Registered line magic `run_viz`
# 2020-10-03 18:09:19,793 - kedro.io.data_catalog - INFO - Loading data from `raw_excess_deaths` (CSVDataSet)...

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df = df.loc[df["region"] == df["country"]]
df["country"] = df.country.str.lower()

# %%
pf = ProfileReport(df)
pf.to_widgets()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e8507317c533> in <module>
#       1 pf = ProfileReport(df)
# ----> 2 pf.to_widgets()
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas_profiling\profile_report.py in to_widgets(self)
#     403         from IPython.core.display import display
#     404
# --> 405         display(self.widgets)
#     406
#     407     def _repr_html_(self):
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas_profiling\profile_report.py in widgets(self)
#     189     def widgets(self):
#     190         if self._widgets is None:
# --> 191             self._widgets = self._render_widgets()
#     192         return self._widgets
#     193
#
# c:\users\marc_\.conda\envs\datathon-2\lib\site-packages\pandas_profiling\profile_report.py in _render_widgets(self)
# ...

# %%
df[df["week"] == 36]
# Out:
#            country                                      region region_code  \
# 35         Austria                                     Austria           0
# 625          Chile                                   TarapacÃ¡       CL-TA
# 662          Chile                                 Antofagasta       CL-AN
# 699          Chile                                     Atacama       CL-AT
# 736          Chile                                    Coquimbo       CL-CO
# 773          Chile                                 ValparaÃ­so       CL-VS
# 810          Chile        Libertador General Bernardo OHiggins       CL-LI
# 847          Chile                                       Maule       CL-ML
# 884          Chile                                      Biobio       CL-BI
# 921          Chile                                  AraucanÃ­a       CL-AR
# 958          Chile                                   Los Lagos       CL-LL
# ...
