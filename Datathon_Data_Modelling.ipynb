# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/mustafamerchant/Documents/final2.csv")

# %%
data
# Out:
#              Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0             Afghanistan                0.376387            0.389332
# 1                  Angola                1.718440            0.389332
# 2                 Albania                3.530558            0.389332
# 3                 Andorra                2.905455            0.389332
# 4    United Arab Emirates                2.129742            0.389332
# ..                    ...                     ...                 ...
# 183                Kosovo                3.973709            0.389332
# 184           Yemen, Rep.                0.674093            0.064500
# 185          South Africa                2.800000            0.192000
# 186                Zambia                2.668822            0.329500
# 187              Zimbabwe                2.470372            0.389332
#
#      handwashing_pct  glbl_population_pct  Health_exp_pct_GDP_2016  \
# ...

# %%
data["death to confirmed ratio per 1000"] = data["Deaths_per_1000"]/data["confirmed_cases_per_1000"]

# %%
data
# Out:
#              Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0             Afghanistan                0.376387            0.389332
# 1                  Angola                1.718440            0.389332
# 2                 Albania                3.530558            0.389332
# 3                 Andorra                2.905455            0.389332
# 4    United Arab Emirates                2.129742            0.389332
# ..                    ...                     ...                 ...
# 183                Kosovo                3.973709            0.389332
# 184           Yemen, Rep.                0.674093            0.064500
# 185          South Africa                2.800000            0.192000
# 186                Zambia                2.668822            0.329500
# 187              Zimbabwe                2.470372            0.389332
#
#      handwashing_pct  glbl_population_pct  Health_exp_pct_GDP_2016  \
# ...

# %%
data = data.drop(["Completeness_of_birth_reg_2009-18","Completeness_of_death_reg_2008-16","Health_exp_out_of_pocket_pct_2016",],axis=1)

# %%
data
# Out:
#              Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0             Afghanistan                0.376387            0.389332
# 1                  Angola                1.718440            0.389332
# 2                 Albania                3.530558            0.389332
# 3                 Andorra                2.905455            0.389332
# 4    United Arab Emirates                2.129742            0.389332
# ..                    ...                     ...                 ...
# 183                Kosovo                3.973709            0.389332
# 184           Yemen, Rep.                0.674093            0.064500
# 185          South Africa                2.800000            0.192000
# 186                Zambia                2.668822            0.329500
# 187              Zimbabwe                2.470372            0.389332
#
#      handwashing_pct  glbl_population_pct  Health_exp_pct_GDP_2016  \
# ...

# %%
data = data.drop(["Confirmed","Deaths","death to confirmed ratio per 100"],axis=1)

# %%
data
# Out:
#              Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0             Afghanistan                0.376387            0.389332
# 1                  Angola                1.718440            0.389332
# 2                 Albania                3.530558            0.389332
# 3                 Andorra                2.905455            0.389332
# 4    United Arab Emirates                2.129742            0.389332
# ..                    ...                     ...                 ...
# 183                Kosovo                3.973709            0.389332
# 184           Yemen, Rep.                0.674093            0.064500
# 185          South Africa                2.800000            0.192000
# 186                Zambia                2.668822            0.329500
# 187              Zimbabwe                2.470372            0.389332
#
#      handwashing_pct  glbl_population_pct  Health_exp_pct_GDP_2016  \
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression,f_regression

# %%
data_y = data["death to confirmed ratio per 1000"]

# %%
data = data.drop(["death to confirmed ratio per 1000"],axis=1)

# %%
data = data.drop(["confirmed_cases_per_1000","Deaths_per_1000"],axis=1)

# %%
data["ratio"] = data_y

# %%
data
# Out:
#              Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0             Afghanistan                0.376387            0.389332
# 1                  Angola                1.718440            0.389332
# 2                 Albania                3.530558            0.389332
# 3                 Andorra                2.905455            0.389332
# 4    United Arab Emirates                2.129742            0.389332
# ..                    ...                     ...                 ...
# 183                Kosovo                3.973709            0.389332
# 184           Yemen, Rep.                0.674093            0.064500
# 185          South Africa                2.800000            0.192000
# 186                Zambia                2.668822            0.329500
# 187              Zimbabwe                2.470372            0.389332
#
#      handwashing_pct  glbl_population_pct  Health_exp_pct_GDP_2016  \
# ...

# %%
data.to_csv(r"/Users/mustafamerchant/Documents/azure2.csv",index=False)

# %%
data_x = data

# %%
data_x = data_x.drop(["Country Name"],axis=1)

# %%
X_new = SelectKBest(mutual_info_regression, k=7).fit_transform(data_x, data_y)

# %%
from sklearn.ensemble import AdaBoostRegressor
regr = AdaBoostRegressor(random_state=20, n_estimators=82)

# %%
regr.fit(X_new,data_y)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=82, random_state=20)

# %%
regr.score(X_new,data_y)
# Out:
# 0.7581153015373301
