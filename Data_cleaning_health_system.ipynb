# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
conf_fatal = pd.read_csv("/Users/mustafamerchant/Downloads/Datasets/00 Core/Novel Coronavirus 2019 datasets/covid_19_data.csv")

# %%
conf_fatal
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 116800  116801      09/23/2020  Zaporizhia Oblast         Ukraine
# 116801  116802      09/23/2020            Zeeland     Netherlands
# 116802  116803      09/23/2020           Zhejiang  Mainland China
# 116803  116804      09/23/2020    Zhytomyr Oblast         Ukraine
# 116804  116805      09/23/2020       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
t1 = conf_fatal.groupby(["Country/Region"]).Confirmed.sum().to_frame()

# %%
t1
# Out:
#                                     Confirmed
# Country/Region
#  Azerbaijan                               1.0
# ('St. Martin',)                           2.0
# Afghanistan                         4134817.0
# Albania                              704767.0
# Algeria                             3583765.0
# Andorra                              161490.0
# Angola                               164497.0
# Antigua and Barbuda                    9916.0
# Argentina                          26975742.0
# Armenia                             4078733.0
# Aruba                                    19.0
# Australia                           2348609.0
# Austria                             3613738.0
# Azerbaijan                          3202126.0
# Bahamas                              121428.0
# Bahamas, The                             10.0
# Bahrain                             4735832.0
# Bangladesh                         25972145.0
# Barbados                              19932.0
# ...

# %%
t2 = conf_fatal.groupby(['Country/Region']).Deaths.sum().to_frame()

# %%
t2
# Out:
#                                   Deaths
# Country/Region
#  Azerbaijan                          0.0
# ('St. Martin',)                      0.0
# Afghanistan                     128968.0
# Albania                          20902.0
# Algeria                         162118.0
# ...                                  ...
# Western Sahara                     121.0
# Yemen                            49501.0
# Zambia                           18002.0
# Zimbabwe                         10243.0
# occupied Palestinian territory       0.0
#
# [223 rows x 1 columns]

# %%
temp = pd.merge(t1, t2, on=['Country/Region'])
print(temp.shape)
# Out:
# (223, 2)
#                  Confirmed    Deaths
# Country/Region
#  Azerbaijan            1.0       0.0
# ('St. Martin',)        2.0       0.0
# Afghanistan      4134817.0  128968.0
# Albania           704767.0   20902.0
# Algeria          3583765.0  162118.0

# %%
temp.head(223)
# Out:
#                                 Confirmed    Deaths
# Country/Region
#  Azerbaijan                           1.0       0.0
# ('St. Martin',)                       2.0       0.0
# Afghanistan                     4134817.0  128968.0
# Albania                          704767.0   20902.0
# Algeria                         3583765.0  162118.0
# ...                                   ...       ...
# Western Sahara                     1481.0     121.0
# Yemen                            177772.0   49501.0
# Zambia                           750629.0   18002.0
# Zimbabwe                         394970.0   10243.0
# occupied Palestinian territory       25.0       0.0
#
# [223 rows x 2 columns]

# %%
hospital_beds = pd.read_csv("/Users/mustafamerchant/Downloads/API_SH/API_SH.MED.BEDS.ZS_DS2_en_csv_v2_1346721.csv",skiprows=3)

# %%
hospital_beds
# Out:
#      Country Name Country Code                    Indicator Name  \
# 0           Aruba          ABW  Hospital beds (per 1,000 people)
# 1     Afghanistan          AFG  Hospital beds (per 1,000 people)
# 2          Angola          AGO  Hospital beds (per 1,000 people)
# 3         Albania          ALB  Hospital beds (per 1,000 people)
# 4         Andorra          AND  Hospital beds (per 1,000 people)
# ..            ...          ...                               ...
# 259        Kosovo          XKX  Hospital beds (per 1,000 people)
# 260   Yemen, Rep.          YEM  Hospital beds (per 1,000 people)
# 261  South Africa          ZAF  Hospital beds (per 1,000 people)
# 262        Zambia          ZMB  Hospital beds (per 1,000 people)
# 263      Zimbabwe          ZWE  Hospital beds (per 1,000 people)
#
#      Indicator Code      1960  1961  1962  1963  1964  1965  ...  2011  2012  \
# 0    SH.MED.BEDS.ZS       NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# ...

# %%
hospital_beds['hospital_beds_per_1000'] = hospital_beds.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
hospital_beds = hospital_beds[['Country Name','Country Code','hospital_beds_per_1000']]
hospital_beds.head()
# Out:
#   Country Name Country Code  hospital_beds_per_1000
# 0        Aruba          ABW                     NaN
# 1  Afghanistan          AFG                0.376387
# 2       Angola          AGO                1.718440
# 3      Albania          ALB                3.530558
# 4      Andorra          AND                2.905455

# %%
specialist_doctors = pd.read_csv("/Users/mustafamerchant/Downloads/API_SH-2/API_SH.MED.SAOP.P5_DS2_en_csv_v2_1345400.csv",skiprows=3)
specialist_doctors
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# 1    Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# 2    Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# 3    Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# 4    Specialist surgical workforce (per 100,000 pop...  SH.MED.SAOP.P5   NaN
# ..                                                 ...             ...   ...
# ...

# %%
specialist_doctors['specialist_doctors_pct'] = specialist_doctors.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
specialist_doctors = specialist_doctors[['Country Name','Country Code','specialist_doctors_pct']]
specialist_doctors.head()
# Out:
#   Country Name Country Code  specialist_doctors_pct
# 0        Aruba          ABW                     NaN
# 1  Afghanistan          AFG                    0.03
# 2       Angola          AGO                     NaN
# 3      Albania          ALB                    9.35
# 4      Andorra          AND                   71.69

# %%
health_workers = pd.read_csv("/Users/mustafamerchant/Downloads/API_SH-3/API_SH.MED.CMHW.P3_DS2_en_csv_v2_1351263.csv",skiprows=3)
health_workers
# Out:
#      Country Name Country Code                               Indicator Name  \
# 0           Aruba          ABW  Community health workers (per 1,000 people)
# 1     Afghanistan          AFG  Community health workers (per 1,000 people)
# 2          Angola          AGO  Community health workers (per 1,000 people)
# 3         Albania          ALB  Community health workers (per 1,000 people)
# 4         Andorra          AND  Community health workers (per 1,000 people)
# ..            ...          ...                                          ...
# 259        Kosovo          XKX  Community health workers (per 1,000 people)
# 260   Yemen, Rep.          YEM  Community health workers (per 1,000 people)
# 261  South Africa          ZAF  Community health workers (per 1,000 people)
# 262        Zambia          ZMB  Community health workers (per 1,000 people)
# 263      Zimbabwe          ZWE  Community health workers (per 1,000 people)
#
# ...

# %%
health_workers['health_workers_pct'] = health_workers.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
health_workers = health_workers[['Country Name','Country Code','health_workers_pct']]
health_workers.head()
# Out:
#   Country Name Country Code  health_workers_pct
# 0        Aruba          ABW                 NaN
# 1  Afghanistan          AFG                 NaN
# 2       Angola          AGO                 NaN
# 3      Albania          ALB                 NaN
# 4      Andorra          AND                 NaN

# %%
physicians = pd.read_csv("/Users/mustafamerchant/Downloads/API_SH-4/API_SH.MED.PHYS.ZS_DS2_en_csv_v2_1348462.csv",skiprows=3)

# %%
physicians['physicians_pct'] =physicians.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
physicians = physicians[['Country Name','Country Code','physicians_pct']]
physicians.head()
# Out:
#   Country Name Country Code  physicians_pct
# 0        Aruba          ABW        1.120000
# 1  Afghanistan          AFG        0.176345
# 2       Angola          AGO        0.091911
# 3      Albania          ALB        1.211191
# 4      Andorra          AND        2.939167

# %%
handwashing = pd.read_csv("/Users/mustafamerchant/Downloads/API_SH-5/API_SH.STA.HYGN.ZS_DS2_en_csv_v2_1351290.csv",skiprows=3)

# %%
handwashing['handwashing_pct'] =handwashing.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
handwashing = handwashing[['Country Name','Country Code','handwashing_pct']]
handwashing.head()
# Out:
#   Country Name Country Code  handwashing_pct
# 0        Aruba          ABW              NaN
# 1  Afghanistan          AFG        37.493180
# 2       Angola          AGO        25.705359
# 3      Albania          ALB              NaN
# 4      Andorra          AND              NaN

# %%
health_system = pd.read_csv("/Users/mustafamerchant/Downloads/Datasets/01 Suggested/World development indicators - health systems/2.12_Health_systems.csv")

# %%
health_system
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1          Albania             NaN                Albania
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...

# %%
glbl_population = pd.read_csv('/Users/mustafamerchant/Downloads/API_SP/API_SP.POP.TOTL_DS2_en_csv_v2_1345178.csv',skiprows=3)
glbl_population
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996973.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5454933.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5315355.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17099840.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3070776.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3776681.0
#
# ...

# %%
glbl_population['glbl_population_pct'] =glbl_population.drop(['Country Name','Country Code','Indicator Name','Indicator Code'], axis=1).mean(axis=1)
glbl_population = glbl_population[['Country Name','Country Code','glbl_population_pct']]
glbl_population.head()
# Out:
#   Country Name Country Code  glbl_population_pct
# 0        Aruba          ABW         7.626863e+04
# 1  Afghanistan          AFG         1.836226e+07
# 2       Angola          AGO         1.382323e+07
# 3      Albania          ALB         2.708297e+06
# 4      Andorra          AND         5.154735e+04

# %%
#health_factors = pd.merge(physician_availibility, specialist_doctors, on=['country_name','country_code'])
#health_factors = pd.merge(health_factors, nurses, on=['country_name','country_code'])
health_factors = pd.merge(hospital_beds, health_workers, on=['Country Name','Country Code'])
#health_factors = pd.merge(health_factors, health_system, on=['country_name','country_code'])
#health_factors = pd.merge(health_factors, hospital_beds, on=['Country Name','Country Code'])
health_factors = pd.merge(health_factors, handwashing, on=['Country Name','Country Code'])
#health_factors = pd.merge(health_factors, international_debt, how='left', on=['Country Name','Country Code'])
health_factors = pd.merge(health_factors, glbl_population, on=['Country Name','Country Code'])

print(health_factors.shape)
health_factors.head()
# Out:
# (264, 6)
#   Country Name Country Code  hospital_beds_per_1000  health_workers_pct  \
# 0        Aruba          ABW                     NaN                 NaN
# 1  Afghanistan          AFG                0.376387                 NaN
# 2       Angola          AGO                1.718440                 NaN
# 3      Albania          ALB                3.530558                 NaN
# 4      Andorra          AND                2.905455                 NaN
#
#    handwashing_pct  glbl_population_pct
# 0              NaN         7.626863e+04
# 1        37.493180         1.836226e+07
# 2        25.705359         1.382323e+07
# 3              NaN         2.708297e+06
# 4              NaN         5.154735e+04

# %%
health_factors = pd.merge(health_factors,health_system , left_on="Country Name" , right_on="World_Bank_Name")

# %%
health_factors
# Out:
#                        Country Name Country Code  hospital_beds_per_1000  \
# 0                       Afghanistan          AFG                0.376387
# 1                            Angola          AGO                1.718440
# 2                           Albania          ALB                3.530558
# 3                           Andorra          AND                2.905455
# 4              United Arab Emirates          ARE                2.129742
# 5                         Argentina          ARG                4.676863
# 6                           Armenia          ARM                6.538957
# 7               Antigua and Barbuda          ATG                3.517846
# 8                         Australia          AUS                9.590851
# 9                           Austria          AUT                9.028125
# 10                       Azerbaijan          AZE                8.615230
# 11                          Burundi          BDI                1.033563
# ...

# %%
health_factors = health_factors.drop(['Province_State','Country Code','World_Bank_Name'],axis=1)

# %%
health_factors
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
health_factors['handwashing_pct'] = health_factors['handwashing_pct'] / 100
health_factors.head()
# Out:
#            Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0           Afghanistan                0.376387                 NaN
# 1                Angola                1.718440                 NaN
# 2               Albania                3.530558                 NaN
# 3               Andorra                2.905455                 NaN
# 4  United Arab Emirates                2.129742                 NaN
#
#    handwashing_pct  glbl_population_pct        Country_Region  \
# 0         0.374932         1.836226e+07           Afghanistan
# 1         0.257054         1.382323e+07                Angola
# 2              NaN         2.708297e+06               Albania
# 3              NaN         5.154735e+04               Andorra
# 4              NaN         3.089065e+06  United Arab Emirates
#
#    Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                     10.2                         5.1
# 1                      2.9                        44.1
# ...

# %%
conf = pd.merge(health_factors,t1, left_on="Country Name", right_on="Country/Region")

# %%
conf = conf.drop(["Country/Region"],axis=1)

# %%
conf
# Out:
#                  Country Name  hospital_beds_per_1000  health_workers_pct  \
# 0                 Afghanistan                0.376387                 NaN
# 1                      Angola                1.718440                 NaN
# 2                     Albania                3.530558                 NaN
# 3                     Andorra                2.905455                 NaN
# 4        United Arab Emirates                2.129742                 NaN
# 5                   Argentina                4.676863                 NaN
# 6                     Armenia                6.538957                 NaN
# 7         Antigua and Barbuda                3.517846                 NaN
# 8                   Australia                9.590851            0.095000
# 9                     Austria                9.028125                 NaN
# 10                 Azerbaijan                8.615230                 NaN
# 11                    Burundi                1.033563            0.072000
# ...

# %%
health_factors[(~health_factors["Country Name"].isin(t1["Country/Region"]))]
# Out:
#                   Country Name  hospital_beds_per_1000  health_workers_pct  \
# 34               Cote d'Ivoire                0.908994                 NaN
# 37                 Congo, Rep.                3.273571                 NaN
# 62       Micronesia, Fed. Sts.                3.215460            0.297000
# 83                 Isle of Man                1.744892                 NaN
# 98                    Kiribati                3.644978                 NaN
# 99         St. Kitts and Nevis                5.669078            0.517818
# 102                    Lao PDR                1.181344                 NaN
# 106                  St. Lucia                3.057435                 NaN
# 113           Macao SAR, China                7.708343                 NaN
# 114   St. Martin (French part)                     NaN                 NaN
# 121           Marshall Islands                2.443175                 NaN
# ...

# %%
t1[(~t1["Country/Region"].isin(health_factors["Country Name"]))]
# Out:
#                      Country/Region  Confirmed
# 0                        Azerbaijan        1.0
# 1                   ('St. Martin',)        2.0
# 10                            Aruba       19.0
# 14                          Bahamas   121428.0
# 37                       Cape Verde        1.0
# 50                          Curacao        2.0
# 54                 Diamond Princess   130296.0
# 58                       East Timor        1.0
# 71                    French Guiana      117.0
# 73                           Gambia   139852.0
# 78                        Gibraltar        7.0
# 82                       Guadeloupe      187.0
# 85                         Guernsey        3.0
# 90                         Holy See     2048.0
# 105                          Jersey        6.0
# 112                            Laos     3484.0
# 121                      MS Zaandam     1592.0
# 130                      Martinique      172.0
# 133                         Mayotte       21.0
# ...

# %%
t1['Country/Region'] = t1['Country/Region'].replace(['Venezuela'],'Venezuela, RB')

# %%
t1['Country/Region'] = t1['Country/Region'].replace(['Iran'],'Iran, Islamic Rep.')

# %%
t1['Country/Region'] = t1['Country/Region'].replace(['Ivory Coast'],"Cote d'Ivoire")
t1['Country/Region'] = t1['Country/Region'].replace(['Macau'],'Macao SAR, China')

# %%
t1['Country/Region'] = t1['Country/Region'].replace(['Congo (Kinshasa)'],'Congo, Rep.')

# %%
conf = pd.merge(health_factors,t1, left_on="Country Name", right_on="Country/Region")

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
t2
# Out:
#                                       Deaths
# Country/Region
#  Azerbaijan                              0.0
# ('St. Martin',)                          0.0
# Afghanistan                         128968.0
# Albania                              20902.0
# Algeria                             162118.0
# Andorra                               8482.0
# Angola                                6959.0
# Antigua and Barbuda                    500.0
# Argentina                           556068.0
# Armenia                              76363.0
# Aruba                                    0.0
# Australia                            43490.0
# Austria                             114074.0
# Azerbaijan                           44469.0
# Bahamas                               3451.0
# Bahamas, The                             0.0
# Bahrain                              15810.0
# Bangladesh                          349755.0
# Barbados                              1144.0
# ...

# %%
t2 = t2.reset_index()

# %%
t2["Country"] = t1["Country/Region"]
conf = pd.merge(conf,t2, left_on="Country Name" , right_on = "Country")

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
conf = conf.drop(["Country/Region_x","Country/Region_y","Country","Country_Region"],axis=1)

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
conf.to_csv(r'/Users/mustafamerchant/Documents/final_deaths_conf.csv', index = False)

# %%
conf.isnull().any().sum()
# Out:
# 14

# %%
conf.fillna(health_factors.mean(), inplace=True)

# %%
conf.isnull().any().sum()
# Out:
# 0

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
conf.corr()
# Out:
#                                       hospital_beds_per_1000  \
# hospital_beds_per_1000                              1.000000
# health_workers_pct                                  0.008154
# handwashing_pct                                     0.225226
# glbl_population_pct                                -0.068782
# Health_exp_pct_GDP_2016                             0.243671
# Health_exp_public_pct_2016                          0.428707
# Health_exp_out_of_pocket_pct_2016                  -0.237101
# Health_exp_per_capita_USD_2016                      0.398180
# per_capita_exp_PPP_2016                             0.435413
# External_health_exp_pct_2016                       -0.238193
# Physicians_per_1000_2009-18                         0.657061
# Nurse_midwife_per_1000_2009-18                      0.704406
# Specialist_surgical_per_1000_2008-18                0.651860
# Completeness_of_birth_reg_2009-18                   0.428127
# ...

# %%
conf['confirmed_cases_per_1000'] = (conf['Confirmed'] / conf['glbl_population_pct'])*1000
conf['Deaths_per_1000'] = (conf['Deaths'] / conf['glbl_population_pct'])*1000

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
conf.to_csv(r'/Users/mustafamerchant/Documents/final2.csv',index=False)

# %%
conf = conf.drop(["Completeness_of_birth_reg_2009-18","Completeness_of_death_reg_2008-16"],axis=1)

# %%
conf
# Out:
#                        Country Name  hospital_beds_per_1000  \
# 0                       Afghanistan                0.376387
# 1                            Angola                1.718440
# 2                           Albania                3.530558
# 3                           Andorra                2.905455
# 4              United Arab Emirates                2.129742
# 5                         Argentina                4.676863
# 6                           Armenia                6.538957
# 7               Antigua and Barbuda                3.517846
# 8                         Australia                9.590851
# 9                           Austria                9.028125
# 10                       Azerbaijan                8.615230
# 11                          Burundi                1.033563
# 12                          Belgium                7.338462
# 13                            Benin                0.697212
# 14                     Burkina Faso                0.715120
# ...

# %%
conf.corr()
# Out:
#                                       hospital_beds_per_1000  \
# hospital_beds_per_1000                              1.000000
# health_workers_pct                                  0.008154
# handwashing_pct                                     0.225226
# glbl_population_pct                                -0.068782
# Health_exp_pct_GDP_2016                             0.243671
# Health_exp_public_pct_2016                          0.428707
# Health_exp_out_of_pocket_pct_2016                  -0.237101
# Health_exp_per_capita_USD_2016                      0.398180
# per_capita_exp_PPP_2016                             0.435413
# External_health_exp_pct_2016                       -0.238193
# Physicians_per_1000_2009-18                         0.657061
# Nurse_midwife_per_1000_2009-18                      0.704406
# Specialist_surgical_per_1000_2008-18                0.651860
# Confirmed                                           0.003291
# ...
